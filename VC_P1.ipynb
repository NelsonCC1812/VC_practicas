# %% [markdown]
# > #### ***Nelson Cabrera Cano***

# %% [markdown]
# #### Imports

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Chessboard

# %% [markdown]
# #### Image size

# %%
board_pixels = 8

# %% [markdown]
# #### Image generation

# %%
img = np.zeros((board_pixels, board_pixels,1), dtype = np.uint8)
plt.imshow(img, cmap='gray')

# %% [markdown]
# #### Chessboard generation

# %%
for row in range(0,board_pixels):
    if row % 2:
        for col in range(0, len(img[0])):
            if col%2: img[row][col] = 255
    else:
        for col in range(0, len(img[0])):
            if not col%2: img[row][col] = 255

plt.imshow(img, cmap='gray')

# %% [markdown]
# ### Piet Mondrian

# %% [markdown]
# #### Shape generator

# %%
width, heigth = 1000, 1000
img = np.zeros((width, heigth, 3), dtype=np.uint8)

# %% [markdown]
# #### Image generator

# %%
img[0:400, 0:300] = (230, 10, 30)
img[0:600, 320:500] = (230, 230, 230)
img[620:700, 320:500] = (230, 230, 230)

plt.imshow(img)
